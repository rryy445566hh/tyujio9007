# %%
# 单变量描述统计


##  无序类别变量描述统计


import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei'] #设置字体
df = pd.read_spss(R'C:\Users\lenovo\Desktop\tyujio9007\data\identity.sav')

# %%
df['民族'].value_counts(normalize=True)
# Out:
# 民族
# 汉族      0.424277
# 回族      0.152601
# 藏族      0.057803
# 蒙古族     0.057803
# 壮族      0.054335
# 土家族     0.053179
# 维吾尔族    0.053179
# 苗族      0.039306
# 彝族      0.017341
# 白族      0.017341
# 满族      0.012717
# 哈萨克族    0.011561
# 瑶族      0.009249
# 布依族     0.008092
# 侗族      0.005780
# 东乡族     0.004624
# 黎族      0.003468
# 哈尼族     0.003468
# 水族      0.002312
# 仫佬族     0.002312
# 羌族      0.002312
# 畲族      0.001156
# 土族      0.001156
# 其他      0.001156
# 保安族     0.001156
# 裕固族     0.001156
# 毛难族     0.001156
# Name: proportion, dtype: float64

# %%
x = df['政治面貌'].value_counts().index
y = df['政治面貌'].value_counts(normalize=True).values * 100
fig, ax2 = plt.subplots()
labels = df['政治面貌'].value_counts().index
ax2.pie(y, autopct='%1.1f%%', labels=labels, textprops=dict(color="w"))
plt.show()

# %%
#有序定变量描述统计，可增加累计比例的统计。可采纳饼图或柱状图进行可视化。
df['年级'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       大二
# 1       大四
# 2       大四
# 3       大四
# 4       大四
#       ...
# 900    NaN
# 901    NaN
# 902    NaN
# 903    NaN
# 904    NaN
# Name: 年级, Length: 905, dtype: category
# Categories (5, object): ['大一', '大三', '大二', '大四', '预科']>

# %%
from pyreadstat import pyreadstat

国家认同调查数据表,metadata = pyreadstat.read_sav(R'C:\Users\lenovo\Desktop\tyujio9007\data\identity.sav')
result = 国家认同调查数据表['会打多少分'].value_counts(sort=False)

# %%
国家认同调查数据表['年级'].value_counts(sort=False)
# Out:
# 年级
# 2.0    278
# 4.0     94
# 3.0    172
# 1.0    307
# 0.0     14
# Name: count, dtype: int64

# %%
result = 国家认同调查数据表['年级'].value_counts(sort=False)
df_result = pd.DataFrame(result)
df_result['累计求和'] = df_result['count'].cumsum()
df_result['新变量1'] = 1
df_result['新变量2'] = df_result.新变量1 + 1
df_result['比例'] = 国家认同调查数据表['年级'].value_counts(normalize=True)
df_result['累计比例'] = df_result['比例'].cumsum

# %%
x = df_result.index
y = df_result['count'].values
fig, ax2 = plt.subplots()
ax2.scatter(x,y)
plt.show()

# %%
x = df_result.index
y = df_result['count'].values
fig, ax2 = plt.subplots()
ax2.bar(x,y)
plt.show()
